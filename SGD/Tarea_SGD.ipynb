# %%
#librerías necesarias
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
#dataset
df = pd.read_csv('ReporteFelicidad_2019.csv')
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#selección de características y target
X = df[[
    "GDP per capita",
    "Social support",
    "Healthy life expectancy",
    "Freedom to make life choices",
    "Generosity",
    "Perceptions of corruption"
]].values

y = df["Score"].values

#estandarización
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#modelo lineal
lr = LinearRegression()
lr.fit(X_scaled, y)

# Predicciones
y_pred = lr.predict(X_scaled)

# Evaluando
print("Pesos (coeficientes):", lr.coef_)
print("Sesgo (intercepto):", lr.intercept_)
print("MSE:", mean_squared_error(y, y_pred))
# Out:
# Pesos (coeficientes): [0.30790823 0.33526868 0.2602062  0.20779294 0.04650427 0.09162219]
# Sesgo (intercepto): 5.407096153846155
# MSE: 0.2718699574912706

# %%
#implementación sgd
sgd_model = SGDRegressor(max_iter=1000, learning_rate='invscaling',random_state=11)
sgd_model.fit(X_scaled, y)

#reemplazando los pesos con los del modelo lineal
sgd_model.coef_ = lr.coef_.copy()
sgd_model.intercept_ = np.array([lr.intercept_])

#entrenando nuevamente para refinar con SGD los pesos
sgd_model.fit(X_scaled, y)

y_pred_sgd = sgd_model.predict(X_scaled)
mse_sgd = mean_squared_error(y, y_pred_sgd)

print("Modelo optimizado con SGD:")
print("Pesos:", sgd_model.coef_)
print("Sesgo:", sgd_model.intercept_)
print("MSE:", mse_sgd, "\n")
# Out:
# Modelo optimizado con SGD:
# Pesos: [0.29238966 0.33774594 0.27546905 0.20685824 0.04062026 0.10043971]
# Sesgo: [5.38662088]
# MSE: 0.2724403254662294

# %%
print(f"Predicciones: {y_pred_sgd}")
# Out:
# Predicciones: [7.01471123 7.09661047 7.17115391 6.91736082 6.91173061 7.06243293
#  6.95791033 7.04508444 6.94924159 6.71686301 6.96148703 6.2191687
#  6.2560377  6.95422986 6.71487926 6.96581909 6.65302588 6.5622992
#  6.37435179 6.14625671 6.4618961  6.7149136  5.76331945 6.46651203
#  6.14309869 5.86843953 5.56837018 6.04582042 6.55483394 6.27147276
#  6.12711185 5.74102728 6.23322599 7.27851722 5.39104012 6.01582793
#  6.30673752 5.93455832 5.95518053 6.08624019 6.20832934 5.80341632
#  5.79914805 6.43586844 5.57341929 5.49439761 5.95288574 5.66028413
#  5.97517982 5.77382429 6.15647109 6.06187396 5.70042712 5.64362402
#  6.32927573 5.77734815 5.95829862 6.40701286 5.49807953 5.92001367
#  5.37115623 5.52824069 5.85311174 6.15334914 5.60552868 6.20023018
#  4.52227617 5.65380234 5.53852823 5.5467061  5.04195117 5.5917681
#  5.49853485 4.99913812 5.58832298 6.59702888 5.85678374 5.2166864
#  5.52226045 5.8006625  5.63508458 5.21013182 5.5511947  5.51863743
# ...
